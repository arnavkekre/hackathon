# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavkekre/hackathon/blob/main/Studence_Performance_Factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# ## Students who don't have access to internet facilities

# %%
no_internet_studs = df[df['Internet_Access']=='No']
no_internet_studs.head(5)
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 10             17          80                  Low                High
# 56             15          83               Medium                High
# 64             25          98                  Low                High
# 68             22          98               Medium                High
# 70             22          98               Medium                 Low
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 10                         No            8               88           Medium
# 56                         No            5               89              Low
# 64                        Yes            8               56           Medium
# 68                         No            5               69              Low
# 70                        Yes            7               52           Medium
#
#    Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
sns.displot(no_internet_studs, x='Family_Income', hue='Parental_Education_Level' ,element='step', kind='hist')

# %% [markdown]
# we can infere that the students having less/no access to the internet belong mostly from low-medium waged families

# %% [markdown]
# also..

# %% [markdown]
# low Family Income also reflects on the education status of the parents (mostly)

# %%
sns.relplot(no_internet_studs,x='Exam_Score',y='Hours_Studied', hue='Access_to_Resources', kind='scatter')

# %% [markdown]
# hours studied is also exponentially rising(not to be exact) with hours studied, except some exceptionally smart kids..

# %% [markdown]
# low access to resources results in the students getting low marks even though hours studied is at some par with those who have adequate access to resources

# %% [markdown]
# since those who don't have adequate access to study resources, are at a slight less amount of hours studied(comparing maximus) due to lack of proper knowledge based resources

# %% [markdown]
# ####Motivation LVL vs Gender

# %%
sns.displot(no_internet_studs, x='Motivation_Level', hue='Gender', element='step',kind='hist')

# %% [markdown]
# Low Motivation Seen in Rural Areas Among Students Escpecially, In Girls..

# %%
sns.relplot(no_internet_studs,x='Exam_Score', y='Hours_Studied', hue='Motivation_Level', kind='scatter', col='Gender',style='Parental_Involvement')

# %% [markdown]
# ## 🔍 Key Observations
#
# ### Hours Studied vs. Scores (Correlation)
#
# In both genders, more study hours → higher exam scores (but not perfectly linear).
#
# Some students study a lot but still don’t achieve high scores → could be due to low motivation or lack of effective learning methods.
#
# ### Motivation Level
#
# Students with high motivation (green) tend to cluster around higher study hours and better scores.
#
# Low-motivation students (orange) are scattered, many with low scores despite hours studied.
#
# ### Parental Involvement
#
# Higher parental involvement (■) seems linked with better distribution of exam scores.
#
# Low parental involvement (●) is more common in the lower performance range.
#
# ### Gender Comparison
#
# Male and female patterns are similar, but females appear more tightly clustered (less variance in performance).
#
# Male students show a few extreme outliers (very high scores despite low study, or very low scores despite high study).

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
### Gamification :
print("Gamified Learning!")
# Out:
# Gamified Learning!

# %% [markdown]
# ## 🎯 Connecting to Gamified Rural Education
#
# This graph reflects real-world education challenges in rural areas, where study hours alone don’t guarantee success.
#
# ### Problem Highlighted:
#
# Motivation and parental involvement matter as much as study hours.
#
# Rural students often lack both due to limited awareness, fewer resources, or language barriers.
#
# ### How Gamification Can Help:
#
# Boost Motivation:
#
# Introduce badges, leaderboards, daily streaks, small rewards to turn studying into an engaging challenge.
#
# For example, a student with low motivation (orange cluster) can be nudged to improve through interactive quizzes or game missions.
#
# ### Replace Missing Parental Involvement:
#
# In rural settings, parents may not always track performance.
#
# The platform can act as a virtual mentor, sending feedback, reminders, and encouragement messages.
#
# ### Optimize Study Hours:
#
# Instead of asking students to study “more hours,” the platform can ensure effective hours via micro-quizzes, personalized revision games, and adaptive difficulty.
#
# Helps those who study long hours but still don’t improve (seen in graph).
#
# ### Inclusivity for Both Genders:
#
# Since both male and female patterns are similar, gamified tools can be designed gender-neutral, ensuring equal accessibility.

# %%
## OHHH fr?
print("Well, this better not be All talks No Shit")

# %% [markdown]
# ## 🚀 How We Can Achieve This Feat
#
# ### Step 1: Data Collection
#
# Gather data on rural students: hours studied, quiz performance, engagement.
#
# Use small offline-first apps (works without internet, syncs later).
#
# ### Step 2: Personalization Engine
#
# Build a recommender system (like we discussed before) to suggest activities based on motivation + performance.
#
# ### Step 3: Gamified Features
#
# Add quizzes with levels (easy → hard), progress bars, and rewards.
#
# Language-localized content for inclusivity.
#
# ### Step 4: Community + Feedback
#
# Replace missing parental guidance by giving teachers/mentors dashboards.
#
# Encourage peer-learning (group challenges, village leaderboard).
#
# ### Step 5: Continuous Evaluation
#
# Track engagement → detect drop in motivation early.
#
# Provide nudges like “You’re close to unlocking your next badge!”

# %%
print("das ist der framework..")
# Out:
# das ist der framework..
