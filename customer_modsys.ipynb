# %% [markdown]
# <a href="https://colab.research.google.com/github/arnavkekre/hackathon/blob/main/customer_modsys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk import *
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
print("This is Customer Message Moderation System\n")
print("To continue, Accept our T&C policy")
# Out:
# This is Customer Message Moderation System
#
# To continue, Accept our T&C policy

# %%
print("📝 Terms & Conditions: Customer Message Moderation System \n 1. Purpose This system is designed to monitor and moderate customer messages to ensure respectful, safe, and constructive communication across our platform.\n 2. Scope of Moderation\n- Messages may be reviewed automatically or manually.\n- Moderation includes filtering for profanity, hate speech, harassment, spam, and other violations of community standards.\n- Messages flagged for review may be temporarily hidden or removed.\n3. User Responsibilities\n- Customers must refrain from sending messages that are abusive, discriminatory, threatening, or otherwise inappropriate.\n- Users agree not to use the messaging system for illegal activities or unauthorized promotions.\n4. Data Handling\n- Message content may be stored and analyzed for moderation purposes.\n- Personal data will be handled in accordance with our Privacy Policy.\n- We do not share message content with third parties except as required by law.\n5. Limitations\n- While we strive to maintain a safe environment, we do not guarantee real-time moderation.\n- Users are responsible for their own communications and may be held accountable for violations.\n6. Enforcement\n- Violations may result in warnings, message deletion, temporary suspension, or permanent ban from the platform.\n- Appeals can be submitted through our support channel.\n7. Changes to Policy\nWe reserve the right to update these terms at any time. Continued use of the messaging system implies acceptance of any changes.")
print()
print("Enter 1 to accept, 0 to decline any further requests: ", sep='->')
x = input()
if x==1:
  pass
else:
  print("Returning Back!")
# Out:
# 📝 Terms & Conditions: Customer Message Moderation System
#  1. Purpose This system is designed to monitor and moderate customer messages to ensure respectful, safe, and constructive communication across our platform.
#  2. Scope of Moderation
# - Messages may be reviewed automatically or manually.
# - Moderation includes filtering for profanity, hate speech, harassment, spam, and other violations of community standards.
# - Messages flagged for review may be temporarily hidden or removed.
# 3. User Responsibilities
# - Customers must refrain from sending messages that are abusive, discriminatory, threatening, or otherwise inappropriate.
# - Users agree not to use the messaging system for illegal activities or unauthorized promotions.
# 4. Data Handling
# - Message content may be stored and analyzed for moderation purposes.
# - Personal data will be handled in accordance with our Privacy Policy.
# - We do not share message content with third parties except as required by law.
# ...

# %% [markdown]
# ## Test/Sample

# %%
train = pd.read_csv('/content/en_dataset_with_stop_words.csv')
train['sentiment'].value_counts()
# Out:
# sentiment
# offensive                                          2954
# normal                                              661
# hateful                                             315
# offensive_hateful                                   252
# offensive_disrespectful                             145
# abusive_offensive                                   115
# offensive_normal                                    114
# hateful_disrespectful                                96
# abusive_hateful                                      90
# fearful_abusive_offensive_hateful_disrespectful      85
# hateful_normal                                       79
# disrespectful_normal                                 69
# fearful_abusive_offensive_hateful_normal             62
# fearful_offensive_hateful_disrespectful_normal       61
# fearful_abusive_offensive_disrespectful_normal       53
# abusive_offensive_hateful_disrespectful_normal       53
# abusive_disrespectful                                50
# ...

# %%
train
# Out:
#       HITId                                              tweet  \
# 0         0  If America had another 8 years of Obama's ideo...
# 1         1  Most Canadians have never met seen or associat...
# 2         2                         Hahaha grow up faggot @URL
# 3         3  @user queue is fucking retarded it makes every...
# 4         4  @user Que ce ne soit pas des Burundais refugie...
# ...     ...                                                ...
# 5642   5642  @user @user @user Maybe but @user who lied abo...
# 5643   5643              @user @user You\u2019re a retard :) x
# 5644   5644  (2/2) like no you fucking twat I'm doing damag...
# 5645   5645            If your bf is retarded guess what u r 2
# 5646   5646             @user whats the ching chong stuff mean
#
#                                          sentiment directness  \
# 0     fearful_abusive_hateful_disrespectful_normal   indirect
# 1                                        offensive   indirect
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %% [markdown]
# Porter Stemmer VS Snowball Stemmer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🧭 When to Use What
# - Use Porter if you want a lightweight, fast stemmer for English-only tasks.
# - Use Snowball if you need better accuracy, multilingual support, or more robust handling of edge cases.
# Since you're working on content filtering and moderation, Snowball might give you cleaner stems for categorization and tagging.

# %%
import string

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer(PorterStemmer.ORIGINAL_ALGORITHM) # Fixed: Use the correct mode
ps.stem('fricking')
# Out:
# 'frick'

# %%
def transform_tweet(tweet):
   tweet = tweet.lower()
   tweet = nltk.word_tokenize(tweet)
   y=[]
   for i in text:
    if i.isalnum():
      y.append(i)
    text=y[:]
    y.clear()
    for i in text:
      if i not in stopwords.words('english') and i not in string.punctuation:
        y.append(i)
      text=y[:]
      y.clear()
    for i in text:
        y.append(ss.stem(i))
    return " ".join(y)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def transform_tweet(tweet):
   tweet = tweet.lower()
   tweet = nltk.word_tokenize(tweet)
   y = []
   for i in tweet: # Fix: Use tweet instead of text
    if i.isalpha():
      y.append(i)
   tweet = y[:] # Fix: Update tweet with filtered tokens
   y.clear()
   for i in tweet: # Fix: Use tweet instead of text
      if i not in stopwords.words('english') and i not in string.punctuation:
        y.append(i)
   tweet = y[:] # Fix: Update tweet with filtered tokens
   y.clear() # Fix: Clear the list after updating tweet
   for i in tweet: # Fix: Use tweet instead of text
       y.append(ps.stem(i)) # Fix: Append stemmed word to y
   return " ".join(y) # Fix: Return the stemmed words as a string

# %%
transform_tweet(train['tweet'][0])
# Out:
# 'america anoth year obama ideologi via hillari well wai shithol countri'

# %%
train['transformed_tweet'] = train['tweet'].apply(transform_tweet)

# %%
train
# Out:
#       HITId                                              tweet  \
# 0         0  If America had another 8 years of Obama's ideo...
# 1         1  Most Canadians have never met seen or associat...
# 2         2                         Hahaha grow up faggot @URL
# 3         3  @user queue is fucking retarded it makes every...
# 4         4  @user Que ce ne soit pas des Burundais refugie...
# ...     ...                                                ...
# 5642   5642  @user @user @user Maybe but @user who lied abo...
# 5643   5643              @user @user You\u2019re a retard :) x
# 5644   5644  (2/2) like no you fucking twat I'm doing damag...
# 5645   5645            If your bf is retarded guess what u r 2
# 5646   5646             @user whats the ching chong stuff mean
#
#                                          sentiment directness  \
# 0     fearful_abusive_hateful_disrespectful_normal   indirect
# 1                                        offensive   indirect
# ...

# %%
X = train[['transformed_tweet','directness','annotator_sentiment','target', 'group']] # Fixed: Use a list to select multiple columns

# %%
y = train[['sentiment']]

# %%
X
# Out:
#                                       transformed_tweet directness  \
# 0     america anoth year obama ideologi via hillari ...   indirect
# 1     canadian never met seen associ person current ...   indirect
# 2                                hahaha grow faggot url   indirect
# 3     user queue fuck retard make everyon feel like ...     direct
# 4     user que ce ne soit pa de burundai refugi aler...   indirect
# ...                                                 ...        ...
# 5642  user user user mayb user li trump us shithol c...   indirect
# 5643                                 user user retard x     direct
# 5644    like fuck twat damag heal ran biotic energi url   indirect
# 5645                                bf retard guess u r   indirect
# 5646                   user what ching chong stuff mean   indirect
#
#                    annotator_sentiment              target          group
# 0     anger_fear_shock_sadness_disgust              origin          other
# ...

# %%
y
# Out:
#                                          sentiment
# 0     fearful_abusive_hateful_disrespectful_normal
# 1                                        offensive
# 2                                        offensive
# 3                                offensive_hateful
# 4                                   hateful_normal
# ...                                            ...
# 5642                                       hateful
# 5643                                       hateful
# 5644                                       hateful
# 5645                                        normal
# 5646                                     offensive
#
# [5647 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

y_encoded = lb.fit_transform(y['sentiment'])

# %%
X = pd.get_dummies(X, columns=['directness', 'annotator_sentiment', 'target', 'group'])
display(X.head())
# Out:
#                                    transformed_tweet  directness_direct  \
# 0  america anoth year obama ideologi via hillari ...              False
# 1  canadian never met seen associ person current ...              False
# 2                             hahaha grow faggot url              False
# 3  user queue fuck retard make everyon feel like ...               True
# 4  user que ce ne soit pa de burundai refugi aler...              False
#
#    directness_indirect  annotator_sentiment_anger_confusion  \
# 0                 True                                False
# 1                 True                                False
# 2                 True                                False
# 3                False                                False
# 4                 True                                False
#
#    annotator_sentiment_anger_confusion_fear_disgust  \
# 0                                             False
# 1                                             False
# ...

# %%
y_encoded
# Out:
# array([20, 42, 42, ..., 38, 41, 42])

# %%
from sklearn.naive_bayes import ComplementNB
cnb=ComplementNB()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()

# %%
X
# Out:
#                                       transformed_tweet  directness_direct  \
# 0     america anoth year obama ideologi via hillari ...              False
# 1     canadian never met seen associ person current ...              False
# 2                                hahaha grow faggot url              False
# 3     user queue fuck retard make everyon feel like ...               True
# 4     user que ce ne soit pa de burundai refugi aler...              False
# ...                                                 ...                ...
# 5642  user user user mayb user li trump us shithol c...              False
# 5643                                 user user retard x               True
# 5644    like fuck twat damag heal ran biotic energi url              False
# 5645                                bf retard guess u r              False
# 5646                   user what ching chong stuff mean              False
#
#       directness_indirect  annotator_sentiment_anger_confusion  \
# ...

# %% [markdown]
# ## NEW AND IMP PORTION USING HSTACK FOR STACKING TFDIF'D DATA WITH OTHER FEATURES

# %%
from scipy.sparse import hstack

# %%
X_tfidf = tfidf.fit_transform(X['transformed_tweet'])

# %% [markdown]
# **# Other features (convert booleans to int so the model can handle them)**

# %%
other_features=X.drop(columns=['transformed_tweet']).astype(int)

# %% [markdown]
# **# Convert other_features to sparse (so dimensions match TF-IDF)**

# %%
from scipy import sparse

# %%
other_sparse = sparse.csr_matrix(other_features.values)

# %% [markdown]
# **FINAL**

# %%
X_final = hstack([X_tfidf, other_sparse])

# %%
X_final
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 64136 stored elements and shape (5647, 6806)>

# %%
from sklearn.metrics import classification_report

# %%
cnb.fit(X_final, y_encoded)
# Out:
# ComplementNB()

# %%
# Get user input
new_tweet = input("Enter your post: ")

# Transform the tweet
transformed_new_tweet = transform_tweet(new_tweet)

# Vectorize the transformed tweet using the fitted tfidf vectorizer
new_tweet_tfidf = tfidf.transform([transformed_new_tweet]) # tfidf.transform expects an iterable

# Create a sparse matrix for the other features with the correct number of columns (95 columns in this case)
# Assuming all 'other features' are absent for a single input tweet, we can create a matrix of zeros
import numpy as np
from scipy.sparse import csr_matrix

# The number of 'other features' columns is the total number of features in X_final minus the number of TF-IDF features
num_other_features = X_final.shape[1] - new_tweet_tfidf.shape[1]
other_features_sparse = csr_matrix(np.zeros((1, num_other_features)))


# Horizontally stack the TF-IDF features and the other features
new_tweet_final = hstack([new_tweet_tfidf, other_features_sparse])


# Make a prediction using the trained model
prediction = cnb.predict(new_tweet_final)

# Decode the prediction back to the original sentiment label
predicted_sentiment = lb.inverse_transform(prediction)

print(f"The predicted sentiment for your post is: {predicted_sentiment[0]}")
# Out:
# Enter your post: Bro shut the fuck up
# The predicted sentiment for your post is: offensive

# %%
print(classification_report(y_encoded, cnb.predict(X_final)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      0.40      0.57        50
#            2       1.00      1.00      1.00         1
#            3       0.97      0.40      0.57        90
#            4       1.00      0.50      0.67        34
#            5       1.00      0.32      0.49       115
#            6       0.91      0.50      0.65        20
#            7       1.00      0.40      0.57         5
#            8       0.00      0.00      0.00         4
#            9       1.00      0.42      0.59        53
#           10       1.00      0.50      0.67         4
#           11       0.00      0.00      0.00         1
#           12       1.00      0.30      0.46        10
#           13       0.75      0.38      0.50         8
#           14       0.97      0.49      0.65        69
#           15       0.83      0.36      0.50        28
# ...
